# %%
import os
os.chdir(r'C:\Users\abc\Desktop\New folder')
import pandas as pd
import numpy as np
import matplotlib.pyplot
import seaborn as sns

sns.set_style('whitegrid')

# %%
state_name=['Andhra_Pradesh','Arunachal_Pradesh','Assam','Bihar','Chhattisgarh','Gujarat','Haryana','Himachal_Pradesh','Jharkhand','Karnataka','Kerala','Madhya_Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha','Punjab','Rajasthan','Sikkim','Tamil_Nadu','Telangana','Tripura','Uttar_Pradesh','Uttarakhand']

# %%
dfs=[]
for state in state_name:
    dfs.append(pd.read_csv('{}.csv'.format(state),encoding='ISO-8859-1'))

# %%
for i in range(len(dfs)):
    dfs[i]=dfs[i].loc[:,['Item','2014-15']]
    dfs[i]['State']=state_name[i]

# %%
columns=['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products','Gross State Domestic Product',"Population ('00)",'Per Capita GSDP (Rs.)','Agriculture, forestry and fishing','Crops','Livestock','Forestry and logging','Fishing and aquaculture','Mining and quarrying','Primary','Manufacturing','Electricity, gas, water supply & other utility services','Construction','Secondary','Trade, repair, hotels and restaurants','Hotels & restaurants','Transport, storage, communication & services related to broadcasting','Financial services','Real estate, ownership of dwelling & professional services','Public administration','Other services','Communication & services related to broadcasting','Storage','Air transport','Water transport','Tertiary']

# %%
data=[ [] for _ in range(len(columns))]
for r in range(len(columns)):
    for i in range(len(dfs)):
        data[r].append(dfs[i].loc[(dfs[i].Item==columns[r]),'2014-15'].astype(int))
        
dictionary={}
dictionary['State']=state_name
dictionary.update(dict(zip(columns,data)))
gsdp=pd.DataFrame(dictionary)
gsdp
# Out:
#                 State                   TOTAL GSVA at basic prices  \
# 0      Andhra_Pradesh   27    48825542
# Name: 2014-15, dtype: int32
# 1   Arunachal_Pradesh    27    1636292
# Name: 2014-15, dtype: int32
# 2               Assam   27    18666897
# Name: 2014-15, dtype: int32
# 3               Bihar   27    36184863
# Name: 2014-15, dtype: int32
# 4        Chhattisgarh   27    22228481
# Name: 2014-15, dtype: int32
# 5             Gujarat   27    79131102
# Name: 2014-15, dtype: int32
# 6             Haryana   27    39828404
# Name: 2014-15, dtype: int32
# 7    Himachal_Pradesh    27    9800853
# Name: 2014-15, dtype: int32
# 8           Jharkhand   27    19623166
# Name: 2014-15, dtype: int32
# 9           Karnataka   27    83041338
# Name: 2014-15, dtype: int32
# 10             Kerala   27    48233259
# Name: 2014-15, dtype: int32
# 11     Madhya_Pradesh   27    46016269
# Name: 2014-15, dtype: int32
# 12        Maharashtra  27    157834665
# Name: 2014-15, dtype: int32
# ...

# %%
my_cols=['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products','Gross State Domestic Product',"Population ('00)",'Per Capita GSDP (Rs.)','Agriculture, forestry and fishing','Crops','Livestock','Forestry and logging','Fishing and aquaculture','Mining and quarrying','Primary','Manufacturing','Electricity, gas, water supply & other utility services','Construction','Secondary','Trade, repair, hotels and restaurants','Hotels & restaurants','Transport, storage, communication & services related to broadcasting','Financial services','Real estate, ownership of dwelling & professional services','Public administration','Other services','Communication & services related to broadcasting','Storage','Air transport','Water transport','Tertiary']

# %%
for cols in my_cols:
    gsdp[cols]=gsdp[cols].apply(lambda x:x.iloc[0])

# %%
gsdp=gsdp.sort_values('Per Capita GSDP (Rs.)')
gsdp
# Out:
#                 State  TOTAL GSVA at basic prices  Taxes on Products  \
# 3               Bihar                    36184863            3213546
# 24      Uttar_Pradesh                    97516938           10107396
# 13            Manipur                     1780647              92766
# 2               Assam                    18666897            1725309
# 8           Jharkhand                    19623166            2499171
# 11     Madhya_Pradesh                    46016269            4284700
# 17             Odisha                    30255256            3151184
# 14          Meghalaya                     2289647             213272
# 23            Tripura                     2911319             149345
# 19          Rajasthan                    58158386            5394503
# 4        Chhattisgarh                    22228481            2601791
# 16           Nagaland                     1821495              57674
# 15            Mizoram                     1133289              43084
# ...

# %%
quantiles=gsdp['Per Capita GSDP (Rs.)'].quantile([0,.2, .5, .85, 1])
quantiles
# Out:
# 0.00     33954.00
# 0.20     62989.00
# 0.50    101332.00
# 0.85    152908.75
# 1.00    240274.00
# Name: Per Capita GSDP (Rs.), dtype: float64

# %%
gsdp['Categories'] = pd.cut(gsdp['Per Capita GSDP (Rs.)'], quantiles,labels=['C1','C2','C3','C4'] ,include_lowest=True)

# %%
gsdp
# Out:
#                 State  TOTAL GSVA at basic prices  Taxes on Products  \
# 3               Bihar                    36184863            3213546
# 24      Uttar_Pradesh                    97516938           10107396
# 13            Manipur                     1780647              92766
# 2               Assam                    18666897            1725309
# 8           Jharkhand                    19623166            2499171
# 11     Madhya_Pradesh                    46016269            4284700
# 17             Odisha                    30255256            3151184
# 14          Meghalaya                     2289647             213272
# 23            Tripura                     2911319             149345
# 19          Rajasthan                    58158386            5394503
# 4        Chhattisgarh                    22228481            2601791
# 16           Nagaland                     1821495              57674
# 15            Mizoram                     1133289              43084
# ...

# %%
gsdp.set_index('Categories',inplace=True)

# %%
data=gsdp.groupby('Categories')
data.first()
data=data.sum()
data=data.drop(['TOTAL GSVA at basic prices','Taxes on Products','Subsidies on products',"Population ('00)",'Per Capita GSDP (Rs.)'],axis=1)
data
# Out:
#             Gross State Domestic Product  Agriculture, forestry and fishing  \
# Categories
# C1                             233252066                           56735044
# C2                             125319545                           27407472
# C3                             622828765                           88427015
# C4                             114065899                           15684725
#
#                Crops  Livestock  Forestry and logging  \
# Categories
# C1          39331055   11901405               3673623
# C2          15782803    6826716               3699735
# C3          54577463   23281781               5610080
# C4           8688239    4980803               1195884
#
#             Fishing and aquaculture  Mining and quarrying    Primary  \
# Categories
# C1                          1828960               6096419   62831463
# C2                          1098217               9351471   36758945
# ...

# %%
c1=data.iloc[0]
c1
#for c1 category
# Out:
# Gross State Domestic Product                                            233252066
# Agriculture, forestry and fishing                                        56735044
# Crops                                                                    39331055
# Livestock                                                                11901405
# Forestry and logging                                                      3673623
# Fishing and aquaculture                                                   1828960
# Mining and quarrying                                                      6096419
# Primary                                                                  62831463
# Manufacturing                                                            24987032
# Electricity, gas, water supply & other utility services                   4310264
# Construction                                                             22775948
# ...

# %%
x=c1['Agriculture, forestry and fishing']/c1['Gross State Domestic Product']*100
x1=c1['Crops']/c1['Gross State Domestic Product']*100
x2=c1['Livestock']/c1['Gross State Domestic Product']*100
x3=c1['Forestry and logging']/c1['Gross State Domestic Product']*100
x4=c1['Fishing and aquaculture']/c1['Gross State Domestic Product']*100
x5=c1['Mining and quarrying']/c1['Gross State Domestic Product']*100
x6=c1['Manufacturing']/c1['Gross State Domestic Product']*100
x7=c1['Electricity, gas, water supply & other utility services']/c1['Gross State Domestic Product']*100
x8=c1['Construction']/c1['Gross State Domestic Product']*100
x9=c1['Trade, repair, hotels and restaurants']/c1['Gross State Domestic Product']*100
x10=c1['Hotels & restaurants']/c1['Gross State Domestic Product']*100
x11=c1['Transport, storage, communication & services related to broadcasting']/c1['Gross State Domestic Product']*100
x12=c1['Financial services']/c1['Gross State Domestic Product']*100
x13=c1['Real estate, ownership of dwelling & professional services']/c1['Gross State Domestic Product']*100
x14=c1['Public administration']/c1['Gross State Domestic Product']*100
x15=c1['Other services']/c1['Gross State Domestic Product']*100
x16=c1['Communication & services related to broadcasting']/c1['Gross State Domestic Product']*100
x17=c1['Storage']/c1['Gross State Domestic Product']*100
x18=c1['Air transport']/c1['Gross State Domestic Product']*100
x19=c1['Water transport']/c1['Gross State Domestic Product']*100

# %%
#x=24.32 for Agriculture, forestry and fishing
#x1=16.86 for crops
#x6=10.71 for Manufacturing
#x9=11.78 for Trade, repair, hotels and restaurants
#x13=10.365 for Real estate, ownership of dwelling & professional services

# %%
c2=data.iloc[1]
c2
#for c2 category
# Out:
# Gross State Domestic Product                                            125319545
# Agriculture, forestry and fishing                                        27407472
# Crops                                                                    15782803
# Livestock                                                                 6826716
# Forestry and logging                                                      3699735
# Fishing and aquaculture                                                   1098217
# Mining and quarrying                                                      9351471
# Primary                                                                  36758945
# Manufacturing                                                            17366065
# Electricity, gas, water supply & other utility services                   3453045
# Construction                                                             11043032
# ...

# %%
y=c2['Agriculture, forestry and fishing']/c2['Gross State Domestic Product']*100
y1=c2['Crops']/c2['Gross State Domestic Product']*100
y2=c2['Livestock']/c2['Gross State Domestic Product']*100
y3=c2['Forestry and logging']/c2['Gross State Domestic Product']*100
y4=c2['Fishing and aquaculture']/c2['Gross State Domestic Product']*100
y5=c2['Mining and quarrying']/c2['Gross State Domestic Product']*100
y6=c2['Manufacturing']/c2['Gross State Domestic Product']*100
y7=c2['Electricity, gas, water supply & other utility services']/c2['Gross State Domestic Product']*100
y8=c2['Construction']/c2['Gross State Domestic Product']*100
y9=c2['Trade, repair, hotels and restaurants']/c2['Gross State Domestic Product']*100
y10=c2['Hotels & restaurants']/c2['Gross State Domestic Product']*100
y11=c2['Transport, storage, communication & services related to broadcasting']/c2['Gross State Domestic Product']*100
y12=c2['Financial services']/c2['Gross State Domestic Product']*100
y13=c2['Real estate, ownership of dwelling & professional services']/c2['Gross State Domestic Product']*100
y14=c2['Public administration']/c2['Gross State Domestic Product']*100
y15=c2['Other services']/c2['Gross State Domestic Product']*100
y16=c2['Communication & services related to broadcasting']/c2['Gross State Domestic Product']*100
y17=c2['Storage']/c2['Gross State Domestic Product']*100
y18=c2['Air transport']/c2['Gross State Domestic Product']*100
y19=c2['Water transport']/c2['Gross State Domestic Product']*100

# %%
#top 3/4/5 subcategory in C2 are
#Agriculture, forestry and fishing(21.87)
#Crops(12.59)
#Manufacturing(13.85)
#Construction(8.81)
#Trade, repair, hotels and restaurants(10.38)

# %%
c3=data.iloc[3]
c3
#for c4 category
# Out:
# Gross State Domestic Product                                            114065899
# Agriculture, forestry and fishing                                        15684725
# Crops                                                                     8688239
# Livestock                                                                 4980803
# Forestry and logging                                                      1195884
# Fishing and aquaculture                                                    819799
# Mining and quarrying                                                       829888
# Primary                                                                  16514614
# Manufacturing                                                            18447437
# Electricity, gas, water supply & other utility services                   2230768
# Construction                                                             12441365
# ...

# %%
z=c3['Agriculture, forestry and fishing']/c3['Gross State Domestic Product']*100
z1=c3['Crops']/c3['Gross State Domestic Product']*100
z2=c3['Livestock']/c3['Gross State Domestic Product']*100
z3=c3['Forestry and logging']/c3['Gross State Domestic Product']*100
z4=c3['Fishing and aquaculture']/c3['Gross State Domestic Product']*100
z5=c3['Mining and quarrying']/c3['Gross State Domestic Product']*100
z6=c3['Manufacturing']/c3['Gross State Domestic Product']*100
z7=c3['Electricity, gas, water supply & other utility services']/c3['Gross State Domestic Product']*100
z8=c3['Construction']/c3['Gross State Domestic Product']*100
z9=c3['Trade, repair, hotels and restaurants']/c3['Gross State Domestic Product']*100
z10=c3['Hotels & restaurants']/c3['Gross State Domestic Product']*100
z11=c3['Transport, storage, communication & services related to broadcasting']/c3['Gross State Domestic Product']*100
z12=c3['Financial services']/c3['Gross State Domestic Product']*100
z13=c3['Real estate, ownership of dwelling & professional services']/c3['Gross State Domestic Product']*100
z14=c3['Public administration']/c3['Gross State Domestic Product']*100
z15=c3['Other services']/c3['Gross State Domestic Product']*100
z16=c3['Communication & services related to broadcasting']/c3['Gross State Domestic Product']*100
z17=c3['Storage']/c3['Gross State Domestic Product']*100
z18=c3['Air transport']/c3['Gross State Domestic Product']*100
z19=c3['Water transport']/c3['Gross State Domestic Product']*100

# %%
#top5 subcategory in c4 are:
#Agriculture, forestry and fishing(13.75)
#Manufacturing(16.17)
#Construction(10.90)
#Trade, repair, hotels and restaurants(13.46)
#Real estate, ownership of dwelling & professional services(13.29)

# %%
c4=data.iloc[2]
c4
#for c3 category
# Out:
# Gross State Domestic Product                                            622828765
# Agriculture, forestry and fishing                                        88427015
# Crops                                                                    54577463
# Livestock                                                                23281781
# Forestry and logging                                                      5610080
# Fishing and aquaculture                                                   4957690
# Mining and quarrying                                                     11613097
# Primary                                                                 100040113
# Manufacturing                                                           108002544
# Electricity, gas, water supply & other utility services                  14541227
# Construction                                                             43975718
# ...

# %%
w=c4['Agriculture, forestry and fishing']/c4['Gross State Domestic Product']*100
w1=c4['Crops']/c4['Gross State Domestic Product']*100
w2=c4['Livestock']/c4['Gross State Domestic Product']*100
w3=c4['Forestry and logging']/c4['Gross State Domestic Product']*100
w4=c4['Fishing and aquaculture']/c4['Gross State Domestic Product']*100
w5=c4['Mining and quarrying']/c4['Gross State Domestic Product']*100
w6=c4['Manufacturing']/c4['Gross State Domestic Product']*100
w7=c4['Electricity, gas, water supply & other utility services']/c4['Gross State Domestic Product']*100
w8=c4['Construction']/c4['Gross State Domestic Product']*100
w9=c4['Trade, repair, hotels and restaurants']/c4['Gross State Domestic Product']*100
w10=c4['Hotels & restaurants']/c4['Gross State Domestic Product']*100
w11=c4['Transport, storage, communication & services related to broadcasting']/c4['Gross State Domestic Product']*100
w12=c4['Financial services']/c4['Gross State Domestic Product']*100
w13=c4['Real estate, ownership of dwelling & professional services']/c4['Gross State Domestic Product']*100
w14=c4['Public administration']/c4['Gross State Domestic Product']*100
w15=c4['Other services']/c4['Gross State Domestic Product']*100
w16=c4['Communication & services related to broadcasting']/c4['Gross State Domestic Product']*100
w17=c4['Storage']/c4['Gross State Domestic Product']*100
w18=c4['Air transport']/c4['Gross State Domestic Product']*100
w19=c4['Water transport']/c4['Gross State Domestic Product']*100

# %%
#for category c3
#top5 are 
#Manufacturing(17.34)
#Agriculture, forestry and fishing(14.19)
#Real estate, ownership of dwelling & professional services(15.36)
#Financial services(6.071)
#transport(6.06)

# %%
#We can conclude that in C4 mostly depend not only on primary but tertiary also 
#Similarly in c2 and c1 and c3 also major contributor is agriculture, forestry and fishing 
#the area of focus is other sectors than primary beacuse in other sectors it require education , so we need to imporve our education
# so that other sectors can contribute to GDP more instead of agriculture, forestry and fishing only./

# %%
#at least two recommendations for each category to improve the per capita GDP.
#1)shifting the distribution of GDP towards the secondary and tertiary sectors,
#2) to increase the seconadry and tertiary one should focus on to  contribute towards education more..
