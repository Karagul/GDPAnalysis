# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Data1-A.csv")
df.head(9)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5       (% Growth over previous year)  2012-13             8.43
# 6       (% Growth over previous year)  2013-14            12.85
# 7       (% Growth over previous year)  2014-15            13.40
# 8       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
mean = df.drop(['All_India GDP','West Bengal1','Andaman & Nicobar Islands','Chandigarh','Delhi','Puducherry'],axis=1).iloc[6:9].mean(axis=0)
mean = mean.sort_values()
mean
# Out:
# Goa                   6.033333
# Meghalaya             6.953333
# Odisha                9.836667
# Sikkim               10.486667
# Jammu & Kashmir      10.900000
# Gujarat              11.126667
# Punjab               11.185000
# Maharashtra          11.260000
# Rajasthan            11.320000
# Jharkhand            11.500000
# Uttarakhand          11.803333
# Haryana              11.846667
# Uttar Pradesh        11.940000
# Himachal Pradesh     12.280000
# Tamil Nadu           12.336667
# Kerala               12.583333
# Madhya Pradesh       12.626667
# Assam                12.650000
# Telangana            12.763333
# Bihar                13.603333
# Chhattisgarh         13.703333
# Andhra Pradesh       14.033333
# Karnataka            14.120000
# Arunachal Pradesh    14.413333
# Manipur              14.610000
# Nagaland             16.415000
# Tripura              17.030000
# Mizoram              17.700000
# dtype: float64

# %%
p = mean.plot(figsize=(15,5),kind="bar",fontsize=16)
p.set_title("Average Growth of States", fontsize=18);
p.set_xlabel("States", fontsize=18);
p.set_ylabel("Average", fontsize=18);

# %%
# Mizoram is increasing and Goa is decreasing

# %%
z= mean.mean()
z
# Out:
# 12.406822916666666

# %%
# average is 12.40(approx) and for my Uttarpradesh (hometown) it's 11.94 so it's lower than the average GDP of the total states.

# %%
df.head(9)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5       (% Growth over previous year)  2012-13             8.43
# 6       (% Growth over previous year)  2013-14            12.85
# 7       (% Growth over previous year)  2014-15            13.40
# 8       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
z=df.iloc[4]
z1=z.drop(['Puducherry','Delhi','Chandigarh','All_India GDP','Items  Description','Duration','Himachal Pradesh','Maharashtra','Manipur','Mizoram','Nagaland','Punjab','Rajasthan','Tripura','West Bengal1','Andaman & Nicobar Islands'])
s= pd.to_numeric(z1, errors='coerce')
s=s.sort_values()
s
# Out:
# Sikkim                 16637.0
# Arunachal Pradesh      18784.0
# Meghalaya              26745.0
# Goa                    45002.0
# Jammu & Kashmir       118387.0
# Uttarakhand           184091.0
# Assam                 224234.0
# Jharkhand             241955.0
# Chhattisgarh          260776.0
# Odisha                341887.0
# Bihar                 413503.0
# Haryana               485184.0
# Madhya Pradesh        543975.0
# Telangana             575631.0
# Kerala                588337.0
# Andhra Pradesh        609934.0
# Gujarat               994316.0
# Karnataka            1027068.0
# Uttar Pradesh        1153795.0
# Tamil Nadu           1212668.0
# Name: 4, dtype: float64

# %%
x = s.plot(figsize=(15,5),kind="bar",fontsize=16)
x.set_title("Total GDP of States(2015-16)", fontsize=18);
x.set_xlabel("States", fontsize=18);
x.set_ylabel("GDP", fontsize=18);

# %%
#top 5 states are Tamil Nadu,Uttar Pradesh,Karnataka,Gujrat,Andra Pradesh
#bottom 5 states are Sikkim,Arunachal,Meghalaya,Goa,J&K
